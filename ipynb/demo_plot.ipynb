# %%
import numpy as np

# %%
np.set_printoptions(precision=3, suppress=True)

# %%
axis = np.load('../parsimax_axis.npy')
rotated = np.load("../parsimax_rotated.npy")
word_list = pd.read_csv("../word_list.csv")
word_list = list(word_list.iloc[:,1])

# %%
np.savetxt('../rotated.csv',rotated,delimiter=',')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns
import pandas as pd

# %%
rotated
# Out:
# array([[-0.   ,  0.   ,  0.   , ..., -0.   ,  0.002,  0.002],
#        [ 0.   , -0.001, -0.002, ..., -0.001,  0.001, -0.   ],
#        [ 0.001, -0.001,  0.002, ...,  0.001, -0.002,  0.002],
#        ...,
#        [-0.001,  0.   ,  0.003, ...,  0.   ,  0.002, -0.002],
#        [-0.   , -0.001, -0.   , ...,  0.001, -0.002,  0.003],
#        [-0.001, -0.001, -0.001, ...,  0.001,  0.002,  0.001]], dtype=float32)

# %%
#seabornのheatmapで同じように描いていくぞ
df = pd.DataFrame(rotated)
df.index = word_list

# %%
df
# Out:
#                   0         1         2         3         4         5   \
# areas      -0.000109  0.000292  0.000368  0.000603  0.001602  0.001476
# make        0.000163 -0.000552 -0.001634 -0.001679 -0.002271 -0.000775
# into        0.000771 -0.000919  0.001504 -0.001067  0.000301 -0.000352
# towards     0.000482  0.000318  0.000380  0.000492 -0.002080 -0.000756
# those       0.000656  0.000993 -0.000006  0.000029  0.000765 -0.000115
# kingdom    -0.000379  0.000411  0.002496 -0.001936  0.004892  0.001224
# associated -0.002257 -0.001079 -0.001750 -0.001258 -0.000217 -0.000403
# england     0.001756  0.001378  0.002025  0.000984  0.000931  0.001713
# brought     0.000861  0.000507  0.002219 -0.000212 -0.001012  0.002243
# land        0.000648 -0.001801  0.000573 -0.000939  0.001934  0.000154
# six        -0.000791 -0.000245  0.000382  0.000298  0.002830  0.001264
# l          -0.000235  0.001038  0.001108  0.000888 -0.000245  0.002470
# ...

# %%
result = []
for i in df.columns:
    df.sort_values(i,ascending=False,inplace=True)
    top = df.head(10).index
    result.append(top)

# %%
pd.DataFrame(result)
# Out:
#               0           1            2           3           4  \
# 0        united    commonly         took      became        army
# 1          been         led            n        army         won
# 2          been     century           bc        york      become
# 3           can      should         must        does      recent
# 4       century      states      kingdom           e       civil
# 5          isbn          my            i         war           e
# 6          does          do          are        been          is
# 7        africa     economy      america        west   australia
# 8        member      united          has    football     african
# 9      external        less       rather        more      united
# 10    developed      recent    important        used       known
# 11          age         war         than       least      become
# 12            u       civil        cause        have        such
# ...

# %%
df.sort_values(4,ascending=False,inplace=True)
plt.figure(figsize=(12, 9))
sns.heatmap(df.head(20))
